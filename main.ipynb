# %% [markdown]
# # Data Preprocessing

# %%
from trucker_traces import process_data

HEADERS = [
    "truck_status", "slot", "task_code", "task_description",
    "start_time", "end_time", "duration", "vehicle"
]

LOG_TRUCKER_STATUSES = ["Solo", "Manuelle Buchung", "Leer"]

data = process_data(
    "input/Rohdaten.xlsx",
    headers=HEADERS,
    log_statuses=LOG_TRUCKER_STATUSES
)

data.to_excel(
    "output/Prozessierte_Daten.xlsx"
)
